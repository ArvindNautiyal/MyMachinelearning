# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('/spam.csv',encoding='latin-1')

# %%
data.sample(10)
# Out:
#        v1                                                 v2 Unnamed: 2  \
# 4587  ham  I wanted to wish you a Happy New Year and I wa...        NaN
# 2579  ham     I dunno until when... Lets go learn pilates...        NaN
# 3626  ham  Still chance there. If you search hard you wil...        NaN
# 3115  ham                Uncle Abbey! Happy New Year. Abiola        NaN
# 4874  ham  I know dat feelin had it with Pete! Wuld get w...        NaN
# 4417  ham                         When you get free, call me        NaN
# 2126  ham           You do got a shitload of diamonds though        NaN
# 584   ham  So how's scotland. Hope you are not over showi...        NaN
# 562   ham  Geeeee ... I love you so much I can barely sta...        NaN
# 966   ham  I am not sure about night menu. . . I know onl...        NaN
#
#      Unnamed: 3 Unnamed: 4
# 4587        NaN        NaN
# 2579        NaN        NaN
# 3626        NaN        NaN
# 3115        NaN        NaN
# 4874        NaN        NaN
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5572 entries, 0 to 5571
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   v1          5572 non-null   object
#  1   v2          5572 non-null   object
#  2   Unnamed: 2  50 non-null     object
#  3   Unnamed: 3  12 non-null     object
#  4   Unnamed: 4  6 non-null      object
# dtypes: object(5)
# memory usage: 217.8+ KB

# %%
data.isnull().sum()
# Out:
# v1               0
# v2               0
# Unnamed: 2    5522
# Unnamed: 3    5560
# Unnamed: 4    5566
# dtype: int64

# %%
data.drop(columns=['Unnamed: 2','Unnamed: 3','Unnamed: 4'],inplace=True)

# %%
data.head()
# Out:
#      v1                                                 v2
# 0   ham  Go until jurong point, crazy.. Available only ...
# 1   ham                      Ok lar... Joking wif u oni...
# 2  spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3   ham  U dun say so early hor... U c already then say...
# 4   ham  Nah I don't think he goes to usf, he lives aro...

# %%
data.rename(columns={'v1':'Spam/Ham','v2':'Message'},inplace=True)

# %%
data.sample(2)
# Out:
#      Spam/Ham                          Message
# 4445      ham  Merry christmas to u too annie!
# 74        ham             U can call me now...

# %%
from sklearn.preprocessing import LabelEncoder
encoder = LabelEncoder()
data['Spam/Ham'] = encoder.fit_transform(data['Spam/Ham'])

# %%
data.head()
# Out:
#    Spam/Ham                                            Message
# 0         0  Go until jurong point, crazy.. Available only ...
# 1         0                      Ok lar... Joking wif u oni...
# 2         1  Free entry in 2 a wkly comp to win FA Cup fina...
# 3         0  U dun say so early hor... U c already then say...
# 4         0  Nah I don't think he goes to usf, he lives aro...

# %%
data.duplicated().sum()
# Out:
# 403

# %%
data.drop_duplicates(keep='first',inplace=True)

# %%
data.shape
# Out:
# (5169, 2)

# %%
data.duplicated().sum()
# Out:
# 0

# %% [markdown]
# EDA

# %%
data['Spam/Ham'].value_counts()
# Out:
# Spam/Ham
# 0    4516
# 1     653
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt

# %%
fig , ax = plt.subplots()
ax.pie(data['Spam/Ham'].value_counts(),labels=['Ham','Spam'],startangle=90,autopct="%0.2f")
plt.show()

# %%
# !pip install nltk

# %%
import nltk

# %%
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
data['Total Character'] = data['Message'].apply(len)

# %%
data.head()
# Out:
#    Spam/Ham                                            Message  \
# 0         0  Go until jurong point, crazy.. Available only ...
# 1         0                      Ok lar... Joking wif u oni...
# 2         1  Free entry in 2 a wkly comp to win FA Cup fina...
# 3         0  U dun say so early hor... U c already then say...
# 4         0  Nah I don't think he goes to usf, he lives aro...
#
#    Total Character
# 0              111
# 1               29
# 2              155
# 3               49
# 4               61

# %%
data['word'] = data['Message'].apply(lambda x:len(nltk.word_tokenize(x)))

# %%
data.head()
# Out:
#    Spam/Ham                                            Message  \
# 0         0  Go until jurong point, crazy.. Available only ...
# 1         0                      Ok lar... Joking wif u oni...
# 2         1  Free entry in 2 a wkly comp to win FA Cup fina...
# 3         0  U dun say so early hor... U c already then say...
# 4         0  Nah I don't think he goes to usf, he lives aro...
#
#    Total Character  word
# 0              111    24
# 1               29     8
# 2              155    37
# 3               49    13
# 4               61    15

# %%
data['Sentence'] = data['Message'].apply(lambda x:len(nltk.sent_tokenize(x)))

# %%
data.head()
# Out:
#    Spam/Ham                                            Message  \
# 0         0  Go until jurong point, crazy.. Available only ...
# 1         0                      Ok lar... Joking wif u oni...
# 2         1  Free entry in 2 a wkly comp to win FA Cup fina...
# 3         0  U dun say so early hor... U c already then say...
# 4         0  Nah I don't think he goes to usf, he lives aro...
#
#    Total Character  word  Sentence
# 0              111    24         2
# 1               29     8         2
# 2              155    37         2
# 3               49    13         1
# 4               61    15         1

# %%
data.describe()
# Out:
#           Spam/Ham  Total Character         word     Sentence
# count  5169.000000      5169.000000  5169.000000  5169.000000
# mean      0.126330        78.977945    18.455794     1.965564
# std       0.332253        58.236293    13.324758     1.448541
# min       0.000000         2.000000     1.000000     1.000000
# 25%       0.000000        36.000000     9.000000     1.000000
# 50%       0.000000        60.000000    15.000000     1.000000
# 75%       0.000000       117.000000    26.000000     2.000000
# max       1.000000       910.000000   220.000000    38.000000

# %%
data.head(2)
# Out:
#    Spam/Ham                                            Message  \
# 0         0  Go until jurong point, crazy.. Available only ...
# 1         0                      Ok lar... Joking wif u oni...
#
#    Total Character  word  Sentence
# 0              111    24         2
# 1               29     8         2

# %%
data['Spam/Ham'].value_counts()
# Out:
# Spam/Ham
# 0    4516
# 1     653
# Name: count, dtype: int64

# %%
data[data['Spam/Ham'] == 0 ].describe()
# Out:
#        Spam/Ham  Total Character         word     Sentence
# count    4516.0      4516.000000  4516.000000  4516.000000
# mean        0.0        70.459256    17.123782     1.820195
# std         0.0        56.358207    13.493970     1.383657
# min         0.0         2.000000     1.000000     1.000000
# 25%         0.0        34.000000     8.000000     1.000000
# 50%         0.0        52.000000    13.000000     1.000000
# 75%         0.0        90.000000    22.000000     2.000000
# max         0.0       910.000000   220.000000    38.000000

# %%
import seaborn as sns

# %%
sns.histplot(data[data['Spam/Ham'] == 0]['Total Character'])
sns.histplot(data[data['Spam/Ham'] == 1]['Total Character'],color='red')
# Out:
# <Axes: xlabel='Total Character', ylabel='Count'>

# %%
sns.histplot(data[data['Spam/Ham'] == 0]['word'])
sns.histplot(data[data['Spam/Ham'] == 1]['word'],color='red')
# Out:
# <Axes: xlabel='word', ylabel='Count'>

# %% [markdown]
# Text Preprocessing

# %%
data.sample(3)
# Out:
#       Spam/Ham                                            Message  \
# 5492         1  Marvel Mobile Play the official Ultimate Spide...
# 4234         1  FREEMSG: Our records indicate you may be entit...
# 4333         0  Boo what time u get out? U were supposed to ta...
#
#       Total Character  word  Sentence
# 5492              161    33         2
# 4234              157    34         3
# 4333               70    18         3

# %%
def transform_text(text):
  text = text.lower()
  text = nltk.word_tokenize(text)
  y = []
  for i in text:
    if i.isalnum():
      y.append(i)
  text = y[:]
  y.clear()
  for i in text:
    if i not in stopwords.words('english') and i not in string.punctuation:
      y.append(i)
  text = y[:]
  y.clear()
  for i in text:
    y.append(ps.stem(i))
  return " ".join(y)

# %%
data['transformed_text'] = data['Message'].apply(transform_text)

# %%
from nltk.corpus import stopwords
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %%
from nltk.stem.porter import PorterStemmer
ps = PorterStemmer()

# %%
import string
string.punctuation
# Out:
# '!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~'

# %%
data.head()
# Out:
#    Spam/Ham                                            Message  \
# 0         0  Go until jurong point, crazy.. Available only ...
# 1         0                      Ok lar... Joking wif u oni...
# 2         1  Free entry in 2 a wkly comp to win FA Cup fina...
# 3         0  U dun say so early hor... U c already then say...
# 4         0  Nah I don't think he goes to usf, he lives aro...
#
#    Total Character  word  Sentence  \
# 0              111    24         2
# 1               29     8         2
# 2              155    37         2
# 3               49    13         1
# 4               61    15         1
#
#                                     transformed_text
# 0  go jurong point crazi avail bugi n great world...
# 1                              ok lar joke wif u oni
# 2  free entri 2 wkli comp win fa cup final tkt 21...
# 3                u dun say earli hor u c alreadi say
# 4               nah think goe usf live around though

# %%
from wordcloud import WordCloud
wc = WordCloud(width=500,height=500,min_font_size=10,background_color='white')

# %%
spam_wc = wc.generate(data[data['Spam/Ham'] == 1]['transformed_text'].str.cat(sep=" "))

# %%
plt.imshow(spam_wc)

# %%
ham_wc = wc.generate(data[data['Spam/Ham'] == 1]['transformed_text'].str.cat(sep=" "))

# %%
plt.imshow(ham_wc)

# %%
spam_corpus = []
for msg in data[data['Spam/Ham'] == 1]['transformed_text'].tolist():
  for word in msg.split():
    spam_corpus.append(word)

# %%
from collections import Counter
counter = Counter(spam_corpus).most_common(30)
counter
# Out:
# [('call', 320),
#  ('free', 191),
#  ('2', 155),
#  ('txt', 141),
#  ('text', 122),
#  ('u', 119),
#  ('ur', 119),
#  ('mobil', 114),
#  ('stop', 104),
#  ('repli', 103),
#  ('claim', 98),
#  ('4', 97),
#  ('prize', 82),
#  ('get', 74),
#  ('new', 64),
#  ('servic', 64),
#  ('tone', 63),
#  ('send', 60),
#  ('urgent', 57),
#  ('nokia', 57),
#  ('contact', 56),
#  ('award', 55),
#  ('phone', 52),
#  ('cash', 51),
#  ('pleas', 51),
#  ('week', 49),
#  ('win', 48),
#  ('c', 45),
#  ('collect', 45),
#  ('min', 45)]

# %%
ham_corpus = []
for word in data[data['Spam/Ham']==0]['transformed_text'].tolist():
  for word in msg.split():
    ham_corpus.append(word)

# %%
counter2 = Counter(ham_corpus).most_common(30)

# %%
counter2
# Out:
# [('2', 9032),
#  ('2nd', 4516),
#  ('time', 4516),
#  ('tri', 4516),
#  ('contact', 4516),
#  ('u', 4516),
#  ('pound', 4516),
#  ('prize', 4516),
#  ('claim', 4516),
#  ('easi', 4516),
#  ('call', 4516),
#  ('087187272008', 4516),
#  ('now1', 4516),
#  ('10p', 4516),
#  ('per', 4516),
#  ('minut', 4516)]

# %% [markdown]
# Model Buiding

# %%
data.head(1)
# Out:
#    Spam/Ham                                            Message  \
# 0         0  Go until jurong point, crazy.. Available only ...
#
#    Total Character  word  Sentence  \
# 0              111    24         2
#
#                                     transformed_text
# 0  go jurong point crazi avail bugi n great world...

# %%
from sklearn.feature_extraction.text import CountVectorizer
cv = CountVectorizer()

# %%
x = cv.fit_transform(data['transformed_text']).toarray()

# %%
y = data.iloc[:,0].values

# %%
y
# Out:
# array([0, 0, 1, ..., 0, 0, 0])

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=2)

# %%
from sklearn.naive_bayes import GaussianNB,MultinomialNB,BernoulliNB
from sklearn.metrics import accuracy_score,confusion_matrix,precision_score

# %%
gnb = GaussianNB()
mnb = MultinomialNB()
bnb = BernoulliNB()

# %%
gnb.fit(x_train,y_train)
y_pred1 = gnb.predict(x_test)
print(accuracy_score(y_test,y_pred1))
print(confusion_matrix(y_test,y_pred1))
print(precision_score(y_test,y_pred1))
# Out:
# 0.8800773694390716
# [[792 104]
#  [ 20 118]]
# 0.5315315315315315

# %%
mnb.fit(x_train,y_train)
y_pred2 = mnb.predict(x_test)
print(accuracy_score(y_test,y_pred2))
print(confusion_matrix(y_test,y_pred2))
print(precision_score(y_test,y_pred2))
# Out:
# 0.9642166344294004
# [[871  25]
#  [ 12 126]]
# 0.8344370860927153

# %%
bnb.fit(x_train,y_train)
y_pred3 = bnb.predict(x_test)
print(accuracy_score(y_test,y_pred3))
print(confusion_matrix(y_test,y_pred3))
print(precision_score(y_test,y_pred3))
# Out:
# 0.9700193423597679
# [[893   3]
#  [ 28 110]]
# 0.9734513274336283

# %%
from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier()

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import RandomizedSearchCV
from sklearn.model_selection import cross_val_score , ShuffleSplit

# %%
sfold = ShuffleSplit(n_splits=5,test_size=0.2,random_state=42)

# %%
param_grid = {
    'n_neighbors': [2,3,4,5,6,7,8,9,10],
    'algorithm': ['ball_tree','kd_tree','brute'],
    'weights': ['uniform','distance'],
    'p':[1,2]
}

# %%
gcv = GridSearchCV(knn,param_grid,scoring='r2',cv=sfold,refit=True,verbose=2,n_jobs=-1)

# %%
gcv.fit(x,y)
# Out:
# Fitting 5 folds for each of 108 candidates, totalling 540 fits
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-121-dfac00608c4d> in <cell line: 1>()
# ----> 1 gcv.fit(x,y)
#
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_search.py in fit(self, X, y, groups, **fit_params)
#     872                 return results
#     873
# --> 874             self._run_search(evaluate_candidates)
#     875
#     876             # multimetric is determined here because in the case of a callable
#
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_search.py in _run_search(self, evaluate_candidates)
#    1386     def _run_search(self, evaluate_candidates):
#    1387         """Search all candidates in param_grid"""
# -> 1388         evaluate_candidates(ParameterGrid(self.param_grid))
#    1389
#    1390
#
# ...

# %% [markdown]
# Using KNN with HyperParameter tuning model got stucked it took lot of time ..
